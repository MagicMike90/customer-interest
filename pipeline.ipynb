# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import glob
import warnings
from IPython.display import display

# %%
# read whole year data
allFiles = glob.glob("data/*.csv")
df = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
df = pd.concat(list_)

df.columns = map(str.lower, df.columns)

# %%
selected_features = ['marketing code','suburb', 'state','post code','enquired',
                     'loan amount','loan_reason','property_use']
target = 'enquiry status';
whole_set = selected_features + [target]

# %%
df = df[whole_set]
# df = df.replace('On Hold','Rejected')
# convert loan amount to number type, and change string to NaN
df['loan amount'] = pd.to_numeric(df['loan amount'],errors='coerce')

# %%
df = df.dropna(axis=0, how='any')
df = df[~df[target].isin(['In Progress','Just Received','On Hold'])]

# %%
def changeDateType(df): 
    df['enquired'] = pd.DatetimeIndex(df['enquired'])
    df['loan amount'] = df['loan amount'].astype(int)
    df['post code'] = df['post code'].astype(int)
    return df
    
changeDateType(df)
# Out:
#      marketing code            suburb state  post code            enquired  \
# 0             DOM35          Westmead   NSW       2145 2017-07-28 12:06:24
# 2             A9471            Wallan   VIC       3756 2017-11-24 16:22:51
# 4             A9234           Sawtell   NSW       2452 2017-11-25 07:42:51
# 5             A9452         Singleton   NSW       2330 2017-11-25 07:59:03
# 6              GA07         Alfredton   VIC       3350 2017-11-25 15:02:46
# 7              AH04      West Wyalong   NSW       2671 2017-11-26 10:46:40
# 8             A9819           Asquith   NSW       2077 2017-11-26 17:57:26
# 9             A9234     St Johns Park   NSW       2176 2017-11-26 18:03:28
# 10             GA01      Yorkeys Knob   QLD       4878 2017-11-27 15:18:57
# 11            A9432           Panania   NSW       2213 2017-11-30 18:25:03
# 12             GA04          Moranbah   QLD       4744 2017-11-30 20:50:31
# 14            DOM07        Wollongong   NSW       2500 2017-11-30 22:04:54
# 16            A8882            Aspley   QLD       4034 2017-11-30 23:21:23
# 27            A9234      Eltham North   VIC       3095 2017-12-01 05:41:58
# 30            A9234       Maison Dieu   NSW       2330 2017-12-01 06:02:31
# 31            A9234      Banora Point   NSW       2486 2017-12-01 06:10:49
# 38         A5981.03           Prahran   VIC       3181 2017-12-01 07:33:03
# 0             P0001   THURSDAY ISLAND   QLD       4875 2013-10-27 21:58:42
# 1            A12668         BURKETOWN   QLD       4830 2014-06-20 14:32:10
# 2             A9289        BLACK ROCK   VIC       3193 2014-09-18 16:25:24
# 3             P0001         Arncliffe   NSW       2205 2015-05-28 15:52:36
# 4               IPH       CASTLE HILL   NSW       2154 2015-05-29 17:10:48
# 5             P0032       North Bondi   NSW       2026 2015-07-25 15:25:10
# 6             A9234            Narara   NSW       2250 2015-10-17 09:10:34
# 7               OME         PITT TOWN   NSW       2756 2015-11-27 23:07:50
# 8            EDOM11  CURRUMBIN WATERS   QLD       4223 2015-12-01 19:31:26
# 9             A9234          Lewisham   NSW       2049 2016-01-05 11:08:04
# 12            A5981           Ipswich   QLD       4305 2016-01-22 02:09:29
# 30         570000             Buying Again            Investment
# 31         427500             Buying Again             Residence
# 38        1000000          First HomeBuyer             Residence
# 0          260000          First HomeBuyer             Residence
# 1          376000             Buying Again            Investment
# 2          832000  Refinance With Cash Out             Residence
# 3          600000          First HomeBuyer            Investment
# 4          530000                Refinance             Residence
# 5          522500          First HomeBuyer             Residence
# 6          300000                Refinance             Residence
# 7          637908             Buying Again             Residence
# 8          434713             Buying Again             Residence
# 9          300000                Refinance             Residence
# 12         500000             Buying Again             Residence
# 14         280000                Refinance             Residence
# 17          98000             Buying Again                 Other
# ...           ...                      ...                   ...
# 4320       350000             Buying Again             Residence
# 4323       370000          First HomeBuyer             Residence
# 4340       595000                Refinance             Residence
# 4344       270000             Buying Again             Residence
# 4346       185000  Refinance With Cash Out             Residence
# 4350       400000          First HomeBuyer             Residence
# 4351       380000                Refinance             Residence
# 4353       107000  Refinance With Cash Out             Residence
# 4357       700000          First HomeBuyer             Residence
# 4359       230000                Refinance             Residence
# 4360        50000                Refinance             Residence
# 4361       462000          First HomeBuyer             Residence
# 4364       450000          First HomeBuyer             Residence
# 4372            0                Refinance             Residence
# 4376       223000             Buying Again            Investment
# 4377       390000          First HomeBuyer             Residence
# 4378       550000          First HomeBuyer             Residence
# 4379       100000          First HomeBuyer             Residence
# 4380       300000             Buying Again             Residence
# 4382       229000          First HomeBuyer             Residence
# 4383       532100          First HomeBuyer             Residence
# 4384       250000          First HomeBuyer            Investment
# 4385       450000             Buying Again             Residence
# 4386       323000          First HomeBuyer             Residence
# 4387       320000   Buying Again,Refinance  Residence,Investment
# 4388       400000          First HomeBuyer             Residence
# 4390       270000          First HomeBuyer             Residence
# 4391       515000             Buying Again             Residence
# 4392       475000          First HomeBuyer             Residence
# 4394       550000             Buying Again             Residence
#
#      enquiry status
# 0          Rejected
# 2          Rejected
# 4          Rejected
# 5          Rejected
# 6          Rejected
# 7          Rejected
# 8          Rejected
# 9          Rejected
# 10         Rejected
# 11         Accepted
# 12         Rejected
# 14         Rejected
# 16         Rejected
# 27         Rejected
# 30         Rejected
# 31         Rejected
# 38         Rejected
# 0          Accepted
# 1          Accepted
# 2          Accepted
# 3          Rejected
# 4          Accepted
# 5          Rejected
# 6          Rejected
# 7          Accepted
# 8          Accepted
# 9          Rejected
# 12         Rejected
# 14         Rejected
# 17         Rejected
# ...             ...
# 4320       Rejected
# 4323       Rejected
# 4340       Accepted
# 4344       Rejected
# 4346       Accepted
# 4350       Rejected
# 4351       Accepted
# 4353       Accepted
# 4357       Rejected
# 4359       Rejected
# 4360       Rejected
# 4361       Accepted
# 4364       Rejected
# 4372       Rejected
# 4376       Rejected
# 4377       Rejected
# 4378       Rejected
# 4379       Rejected
# 4380       Rejected
# 4382       Rejected
# 4383       Accepted
# 4384       Rejected
# 4385       Rejected
# 4386       Rejected
# 4387       Accepted
# 4388       Rejected
# 4390       Rejected
# 4391       Rejected
# 4392       Rejected
# 4394       Rejected
#
# [31246 rows x 9 columns]

# %%
# filter years
start_date = '2017-01-01' 
end_date = '2017-12-31'
mask = (df['enquired'] > start_date) & (df['enquired'] <= end_date)
df = df.loc[mask].reset_index(drop=True)

# %%
from datetime import datetime
from dateutil.parser import parse

def getDetailDate(df):
    # remove Year feature since it is not important (show below random forest)
    # data_set['Year'] = data_set['Enquired'].dt.year
    df['month'] = df['enquired'].dt.month
    df['day'] = df['enquired'].dt.day
    df['hour'] = df['enquired'].dt.hour
    df['weekday'] = df['enquired'].dt.weekday_name
    
    if("enquired" in df.columns):
        df = df.loc[:,df.columns != 'enquired']
    return df
    
df = getDetailDate(df)

# %%
df.columns = df.columns.str.replace('_', ' ')

# %%
from sklearn.preprocessing import LabelEncoder

class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col].astype(str))
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
X = df[df.keys()]
X = df.loc[:,df.columns != target]
y = df[target]

# %%
category_column = X.select_dtypes(include='object')

le = LabelEncoder()
y = le.fit_transform(y)
le.classes_
# Out:
# array(['Accepted', 'Rejected'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# split data and labels into a training and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y,
                     test_size=0.4,
                     random_state=0,
                     stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from sklearn import svm
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(MultiColumnLabelEncoder(columns=category_column.columns),
                         StandardScaler(),
                         svm.SVC(kernel='rbf',probability=True))
pipeline.fit(X_train, y_train)
predit_labels = pipeline.predict(X_test)
print('Test Accuracy: %.3f' % pipeline.score(X_test, y_test))
# Out:
# Test Accuracy: 0.842

# %%
from sklearn.externals import joblib
joblib.dump(pipeline, 'app/models/lrpipeline.pkl')
# Out:
# ['app/models/lrpipeline.pkl']

# %%
model_columns = list(X.columns)
joblib.dump(model_columns, 'app/models/model_columns.pkl')
# Out:
# ['app/models/model_columns.pkl']

# %%
import json
my_json_string = json.dumps({
    "marketing_code": "P0001",
    "enquired":"27/10/13 21:58",
    "loan amount": "260000",
    "suburb": "THURSDAY ISLAND",
    "state": "QLD",
    "post code": "4875",
    "property_use": "First HomeBuyer",
    "loan_reason": "Refinance"
})
my_json_string
# Out:
# '{"marketing_code": "P0001", "enquired": "27/10/13 21:58", "loan amount": "260000", "suburb": "THURSDAY ISLAND", "state": "QLD", "post code": "4875", "property_use": "First HomeBuyer", "loan_reason": "Refinance"}'

# %%
data = json.loads(my_json_string)
data = pd.DataFrame(data,index=[0])
data.dtypes
# Out:
# enquired          object
# loan amount       object
# loan_reason       object
# marketing_code    object
# post code         object
# property_use      object
# state             object
# suburb            object
# dtype: object

# %%
changeDateType(data)
data = getDetailDate(data)

# %%
data.columns = data.columns.str.replace('_', ' ')

# %%
y_pred = pipeline.predict(data)
pipeline.predict_proba(data)
# Out:
# array([[ 0.63625231,  0.36374769]])
