# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import glob
import warnings
from IPython.display import display

warnings.filterwarnings('ignore')
mpl.rcParams['savefig.dpi'] = 128
mpl.rcParams['figure.dpi'] = 128
# Plot size to 14" x 7"
mpl.rc('figure', figsize = (14, 7))
# Font size to 14
mpl.rc('font', size = 14)
# Do not display top and right frame lines
mpl.rc('axes.spines', top = False, right = False)
# Remove grid lines
mpl.rc('axes', grid = False)
# Set backgound color to white
mpl.rc('axes', facecolor = 'white')

# %%
df = pd.read_csv("2011-2017_short.csv")

# %%
from sklearn.preprocessing import LabelEncoder

class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col].astype(str))
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
category_column = X.select_dtypes(include='object')

# %%
df.dtypes
# Out:
# marketing code     object
# loan amount       float64
# property use       object
# enquiry status     object
# year                int64
# month               int64
# day                 int64
# hour                int64
# weekday             int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

target = 'enquiry status';
# df = df.iloc[:number_of_rows]
X = df[df.keys()]
X = df.loc[:,df.columns != target]

le = LabelEncoder()
y = df[target]
y = le.fit_transform(y)

# %%
X = MultiColumnLabelEncoder(columns=category_column.columns).fit_transform(X)

# %%
# Out:
# marketing code      int64
# loan amount       float64
# property use        int64
# year                int64
# month               int64
# day                 int64
# hour                int64
# weekday             int64
# dtype: object

# %%
from sklearn.covariance import EllipticEnvelope

# Create detector
outlier_detector = EllipticEnvelope(contamination=.1)

# Fit detector
outlier_detector.fit(X)

# Predict outliers
result = outlier_detector.predict(X)

for i in range(len(result)) :
    if result[i] < -1:
        print(i)

# %%
# Create one feature
feature = X.iloc[:,1]

# Create a function to return index of outliers
def indicies_of_outliers(x):
    q1, q3 = np.percentile(x, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr * 1.5)
    upper_bound = q3 + (iqr * 1.5)
    return np.where((x > upper_bound) | (x < lower_bound))

# Run function
indicies_of_outliers(feature)
# Out:
# (array([    60,    112,    159, ..., 198152, 198266, 198285]),)

# %%
from sklearn.cluster import KMeans

# # Create DataFrame
# dataframe = pd.DataFrame(X, columns=["feature_1", "feature_2"])

# Make k-means clusterer
clusterer = KMeans(3, random_state=0)

# Fit clusterer
clusterer.fit(X)

# Predict values
X["group"] = clusterer.predict(X)

# %%
X["group"].value_counts()
# Out:
# 1    163506
# 0     34558
# 2       246
# Name: group, dtype: int64

# %%
# X[X["group"] == 1]

# %%
from sklearn.externals import joblib
model_columns = joblib.load('app/models/model_columns.pkl')

# %%
model_columns
# Out:
# ['loan amount',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'weekday',
#  'marketing code_1824',
#  'marketing code_2405',
#  'marketing code_2406',
#  'marketing code_2408',
#  'marketing code_2673',
#  'marketing code_2699',
#  'marketing code_2825',
#  'marketing code_2826',
#  'marketing code_3004',
#  'marketing code_3005',
#  'marketing code_3007',
#  'marketing code_3012',
#  'marketing code_3014',
#  'marketing code_3035',
#  'marketing code_3036',
#  'marketing code_446',
#  'marketing code_5030',
#  'marketing code_6500',
#  'marketing code_7001',
#  'marketing code_7063',
#  'marketing code_A1004',
#  'marketing code_A10045',
#  'marketing code_A1005',
#  'marketing code_A111',
#  'marketing code_A1111',
#  'marketing code_A1112',
#  'marketing code_A112',
#  'marketing code_A113',
#  'marketing code_A114',
#  'marketing code_A119',
#  'marketing code_A120',
#  'marketing code_A123',
#  'marketing code_A125',
#  'marketing code_A12665',
#  'marketing code_A12666',
#  'marketing code_A12667',
#  'marketing code_A12668',
#  'marketing code_A12669',
#  'marketing code_A12670',
#  'marketing code_A12671',
#  'marketing code_A12678',
#  'marketing code_A12679',
#  'marketing code_A12680',
#  'marketing code_A127',
#  'marketing code_A130',
#  'marketing code_A132',
#  'marketing code_A133',
#  'marketing code_A137',
#  'marketing code_A138',
#  'marketing code_A139',
#  'marketing code_A140',
#  'marketing code_A141',
#  'marketing code_A142',
#  'marketing code_A143',
#  'marketing code_A144',
#  'marketing code_A146',
#  'marketing code_A150',
#  'marketing code_A153',
#  'marketing code_A157',
#  'marketing code_A159',
#  'marketing code_A160',
#  'marketing code_A161',
#  'marketing code_A164',
#  'marketing code_A168',
#  'marketing code_A169',
#  'marketing code_A171',
#  'marketing code_A173',
#  'marketing code_A175',
#  'marketing code_A176',
#  'marketing code_A179',
#  'marketing code_A180',
#  'marketing code_A200',
#  'marketing code_A3011',
#  'marketing code_A4005 ',
#  'marketing code_A4006 ',
#  'marketing code_A4007 ',
#  'marketing code_A4014 ',
#  'marketing code_A4017 ',
#  'marketing code_A4023 ',
#  'marketing code_A4024 ',
#  'marketing code_A4027 ',
#  'marketing code_A4132 ',
#  'marketing code_A4141 ',
#  'marketing code_A4153 ',
#  'marketing code_A4335',
#  'marketing code_A4344',
#  'marketing code_A4345',
#  'marketing code_A4351 ',
#  'marketing code_A4374 ',
#  'marketing code_A4895',
#  'marketing code_A5005',
#  'marketing code_A5006',
#  'marketing code_A5007',
#  'marketing code_A5009',
#  'marketing code_A5011',
#  'marketing code_A5012',
#  'marketing code_A5015',
#  'marketing code_A5020',
#  'marketing code_A5094',
#  'marketing code_A5132',
#  'marketing code_A5153',
#  'marketing code_A5157',
#  'marketing code_A5161',
#  'marketing code_A5162',
#  'marketing code_A5230',
#  'marketing code_A5335',
#  'marketing code_A5345',
#  'marketing code_A5350',
#  'marketing code_A5377',
#  'marketing code_A5393',
#  'marketing code_A5423',
#  'marketing code_A5602',
#  'marketing code_A5889',
#  'marketing code_A5891',
#  'marketing code_A5893',
#  'marketing code_A5896',
#  'marketing code_A5897',
#  'marketing code_A5904',
#  'marketing code_A5907',
#  'marketing code_A5908',
#  'marketing code_A5914',
#  'marketing code_A5917',
#  'marketing code_A5925',
#  'marketing code_A5926',
#  'marketing code_A5928',
#  'marketing code_A5929',
#  'marketing code_A5932',
#  'marketing code_A5933',
#  'marketing code_A5934',
#  'marketing code_A5944',
#  'marketing code_A5945',
#  'marketing code_A5946',
#  'marketing code_A5950',
#  'marketing code_A5951',
#  'marketing code_A5952',
#  'marketing code_A5953',
#  'marketing code_A5954',
#  'marketing code_A5955',
#  'marketing code_A5956',
#  'marketing code_A5957',
#  'marketing code_A5958',
#  'marketing code_A5959',
#  'marketing code_A5960',
#  'marketing code_A5961',
#  'marketing code_A5962',
#  'marketing code_A5963',
#  'marketing code_A5966',
#  'marketing code_A5967',
#  'marketing code_A5968',
#  'marketing code_A5972',
#  'marketing code_A5976',
#  'marketing code_A5977',
#  'marketing code_A5980',
#  'marketing code_A5981',
#  'marketing code_A5981.01',
#  'marketing code_A5981.02',
#  'marketing code_A5981.03',
#  'marketing code_A5981.04',
#  'marketing code_A5981.05',
#  'marketing code_A5981.06',
#  'marketing code_A5981.08',
#  'marketing code_A5981.09',
#  'marketing code_A5981.10',
#  'marketing code_A5981.11',
#  'marketing code_A5981.12',
#  'marketing code_A5981.13',
#  'marketing code_A5981.16',
#  'marketing code_A5981.19',
#  'marketing code_A5981.20',
#  'marketing code_A5981.21',
#  'marketing code_A5981.23',
#  'marketing code_A5981.26',
#  'marketing code_A5981.28',
#  'marketing code_A5981.29',
#  'marketing code_A5981.30',
#  'marketing code_A5982',
#  'marketing code_A5983',
#  'marketing code_A5985',
#  'marketing code_A5986',
#  'marketing code_A5988',
#  'marketing code_A5990',
#  'marketing code_A5991',
#  'marketing code_A5992',
#  'marketing code_A5994',
#  'marketing code_A6000',
#  'marketing code_A6005',
#  'marketing code_A6014',
#  'marketing code_A6020',
#  'marketing code_A6021',
#  'marketing code_A6022',
#  'marketing code_A6028',
#  'marketing code_A6132',
#  'marketing code_A6153',
#  'marketing code_A6335',
#  'marketing code_A6345',
#  'marketing code_A6377 ',
#  'marketing code_A6536 ',
#  'marketing code_A6640',
#  'marketing code_A6646 ',
#  'marketing code_A6652',
#  'marketing code_A6653 ',
#  'marketing code_A6654',
#  'marketing code_A6655',
#  'marketing code_A6655.01',
#  'marketing code_A6655.02',
#  'marketing code_A6655.04',
#  'marketing code_A6655.05',
#  'marketing code_A6655.08',
#  'marketing code_A6655.11',
#  'marketing code_A6655.20',
#  'marketing code_A6655.21',
#  'marketing code_A6656',
#  'marketing code_A6657',
#  'marketing code_A6658',
#  'marketing code_A6660',
#  'marketing code_A6891',
#  'marketing code_A6892',
#  'marketing code_A6895',
#  'marketing code_A6902',
#  'marketing code_A6910',
#  'marketing code_A6924',
#  'marketing code_A6925',
#  'marketing code_A6926',
#  'marketing code_A6929',
#  'marketing code_A6936',
#  'marketing code_A6955',
#  'marketing code_A6956',
#  'marketing code_A6958',
#  'marketing code_A6959',
#  'marketing code_A6960',
#  'marketing code_A6965',
#  'marketing code_A6966',
#  'marketing code_A7001',
#  'marketing code_A7002',
#  'marketing code_A7003',
#  'marketing code_A7020',
#  'marketing code_A7022',
#  'marketing code_A7024',
#  'marketing code_A7025',
#  'marketing code_A7027',
#  'marketing code_A7031',
#  'marketing code_A7034',
#  'marketing code_A7035',
#  'marketing code_A7037',
#  'marketing code_A7039',
#  'marketing code_A7042',
#  'marketing code_A7044',
#  'marketing code_A7050',
#  'marketing code_A7051',
#  'marketing code_A7053',
#  'marketing code_A7063',
#  'marketing code_A7064',
#  'marketing code_A7066',
#  'marketing code_A7069',
#  'marketing code_A7071',
#  'marketing code_A7072',
#  'marketing code_A7075',
#  'marketing code_A7076',
#  'marketing code_A7077',
#  'marketing code_A7079',
#  'marketing code_A7081',
#  'marketing code_A7083',
#  'marketing code_A7095',
#  'marketing code_A7097',
#  'marketing code_A7099',
#  'marketing code_A7107',
#  'marketing code_A7108',
#  'marketing code_A7109',
#  'marketing code_A7110',
#  'marketing code_A7111',
#  'marketing code_A7112',
#  'marketing code_A7113',
#  'marketing code_A7114',
#  'marketing code_A7115',
#  'marketing code_A7116',
#  'marketing code_A7117',
#  'marketing code_A7118',
#  'marketing code_A7120',
#  'marketing code_A7121',
#  'marketing code_A7122',
#  'marketing code_A7123',
#  'marketing code_A7124',
#  'marketing code_A7126',
#  'marketing code_A7129',
#  'marketing code_A7132',
#  'marketing code_A7133',
#  'marketing code_A7134',
#  'marketing code_A7135',
#  'marketing code_A7136',
#  'marketing code_A7137',
#  'marketing code_A7138',
#  'marketing code_A7139',
#  'marketing code_A7140',
#  'marketing code_A7141',
#  'marketing code_A7200',
#  'marketing code_A7201',
#  'marketing code_A7202',
#  'marketing code_A7206',
#  'marketing code_A7208',
#  'marketing code_A7209',
#  'marketing code_A7210',
#  'marketing code_A7211',
#  'marketing code_A7212',
#  'marketing code_A7999',
#  'marketing code_A8401 ',
#  'marketing code_A8403',
#  'marketing code_A8405',
#  'marketing code_A8409',
#  'marketing code_A8881',
#  'marketing code_A8882',
#  'marketing code_A8883',
#  'marketing code_A8884',
#  'marketing code_A8885',
#  'marketing code_A8886',
#  'marketing code_A8887',
#  'marketing code_A8888',
#  'marketing code_A8889',
#  'marketing code_A8890',
#  'marketing code_A8891',
#  'marketing code_A8999',
#  'marketing code_A900',
#  'marketing code_A9000',
#  'marketing code_A9001',
#  'marketing code_A9002',
#  'marketing code_A9003',
#  'marketing code_A9009',
#  'marketing code_A901',
#  'marketing code_A9011',
#  'marketing code_A9016',
#  'marketing code_A9017',
#  'marketing code_A9018',
#  'marketing code_A902',
#  'marketing code_A9023',
#  'marketing code_A9025',
#  'marketing code_A9026',
#  'marketing code_A9031',
#  'marketing code_A9034',
#  'marketing code_A9035',
#  'marketing code_A9037',
#  'marketing code_A904',
#  'marketing code_A9044',
#  'marketing code_A9054',
#  'marketing code_A9055',
#  'marketing code_A9056',
#  'marketing code_A9057',
#  'marketing code_A906',
#  'marketing code_A9060',
#  'marketing code_A9065',
#  'marketing code_A9066',
#  'marketing code_A9067',
#  'marketing code_A9072',
#  'marketing code_A9073',
#  'marketing code_A9074',
#  'marketing code_A9075',
#  'marketing code_A9078',
#  'marketing code_A9083',
#  'marketing code_A9085',
#  'marketing code_A9086',
#  'marketing code_A9089',
#  'marketing code_A909',
#  'marketing code_A9091',
#  'marketing code_A9092',
#  'marketing code_A9097',
#  'marketing code_A9098',
#  'marketing code_A9099',
#  'marketing code_A9100',
#  'marketing code_A9102',
#  'marketing code_A9104',
#  'marketing code_A9106',
#  'marketing code_A9108',
#  'marketing code_A911',
#  'marketing code_A9116',
#  'marketing code_A9117',
#  'marketing code_A9118',
#  'marketing code_A9119',
#  'marketing code_A9121',
#  'marketing code_A9122',
#  'marketing code_A9123',
#  'marketing code_A9124',
#  'marketing code_A9126',
#  'marketing code_A9127',
#  'marketing code_A9129',
#  'marketing code_A9131',
#  'marketing code_A9132',
#  'marketing code_A9134',
#  'marketing code_A9135',
#  'marketing code_A9136',
#  'marketing code_A9138',
#  'marketing code_A9139',
#  'marketing code_A9140',
#  'marketing code_A9141',
#  'marketing code_A9145',
#  'marketing code_A9156',
#  'marketing code_A9158',
#  'marketing code_A9159',
#  'marketing code_A9160',
#  'marketing code_A9161',
#  'marketing code_A9165',
#  'marketing code_A9195',
#  'marketing code_A9207',
#  'marketing code_A9211',
#  'marketing code_A9212',
#  'marketing code_A9215',
#  'marketing code_A9223',
#  'marketing code_A9229',
#  'marketing code_A9230',
#  'marketing code_A9234',
#  'marketing code_A9235',
#  'marketing code_A9237',
#  'marketing code_A9244',
#  'marketing code_A9247',
#  'marketing code_A9248',
#  'marketing code_A9249',
#  'marketing code_A9250',
#  'marketing code_A9251',
#  'marketing code_A9259',
#  'marketing code_A9260',
#  'marketing code_A9261',
#  'marketing code_A9263',
#  'marketing code_A9264',
#  'marketing code_A9265',
#  'marketing code_A9266',
#  'marketing code_A9267',
#  'marketing code_A9268',
#  'marketing code_A9272',
#  'marketing code_A9274',
#  'marketing code_A9275',
#  'marketing code_A9277',
#  'marketing code_A9278',
#  'marketing code_A9280',
#  'marketing code_A9281',
#  'marketing code_A9288',
#  'marketing code_A9289',
#  'marketing code_A9290',
#  'marketing code_A9291',
#  'marketing code_A9292',
#  'marketing code_A9293',
#  'marketing code_A9294',
#  'marketing code_A9295',
#  'marketing code_A9296',
#  'marketing code_A9297',
#  'marketing code_A9299',
#  'marketing code_A9300',
#  'marketing code_A9301',
#  'marketing code_A9303',
#  'marketing code_A9304',
#  'marketing code_A9305',
#  'marketing code_A9307',
#  'marketing code_A9308',
#  'marketing code_A9309',
#  'marketing code_A9310',
#  'marketing code_A9312',
#  'marketing code_A9315',
#  'marketing code_A9321',
#  'marketing code_A9323',
#  'marketing code_A9325',
#  'marketing code_A9326',
#  'marketing code_A9327',
#  'marketing code_A9329',
#  'marketing code_A9331',
#  'marketing code_A9335',
#  'marketing code_A9340',
#  'marketing code_A9341',
#  'marketing code_A9343',
#  'marketing code_A9347',
#  'marketing code_A9347.01',
#  'marketing code_A9354',
#  'marketing code_A9359',
#  'marketing code_A9360',
#  'marketing code_A9361',
#  'marketing code_A9362',
#  'marketing code_A9363',
#  'marketing code_A9364',
#  'marketing code_A9365',
#  'marketing code_A9383',
#  'marketing code_A9386',
#  'marketing code_A9387',
#  'marketing code_A9398',
#  'marketing code_A9403',
#  'marketing code_A9410',
#  'marketing code_A9411',
#  'marketing code_A9412',
#  'marketing code_A9413',
#  'marketing code_A9414',
#  'marketing code_A9415',
#  'marketing code_A9416',
#  'marketing code_A9417',
#  'marketing code_A9418',
#  'marketing code_A9426',
#  'marketing code_A9432',
#  'marketing code_A9432.01',
#  'marketing code_A9439',
#  'marketing code_A9442',
#  'marketing code_A9446',
#  'marketing code_A9447',
#  'marketing code_A9449',
#  'marketing code_A9451',
#  'marketing code_A9452',
#  'marketing code_A9454',
#  'marketing code_A9455',
#  'marketing code_A9456',
#  'marketing code_A9457',
#  'marketing code_A9458',
#  'marketing code_A9459',
#  'marketing code_A9460',
#  'marketing code_A9460.01',
#  'marketing code_A9461',
#  'marketing code_A9462',
#  'marketing code_A9463',
#  'marketing code_A9464',
#  'marketing code_A9465',
#  'marketing code_A9467',
#  'marketing code_A9469',
#  'marketing code_A9471',
#  'marketing code_A9473',
#  'marketing code_A9479',
#  'marketing code_A9483',
#  'marketing code_A9486',
#  'marketing code_A9487',
#  'marketing code_A9487.01',
#  'marketing code_A9487.02',
#  'marketing code_A9487.05',
#  'marketing code_A9488',
#  'marketing code_A9489',
#  'marketing code_A9489.01',
#  'marketing code_A9490',
#  'marketing code_A9491',
#  'marketing code_A9492.01',
#  'marketing code_A9492.11',
#  'marketing code_A9493.03',
#  'marketing code_A9493.05',
#  'marketing code_A9499',
#  'marketing code_A9509',
#  'marketing code_A9510',
#  'marketing code_A9511',
#  'marketing code_A9512',
#  'marketing code_A9513',
#  'marketing code_A9514',
#  'marketing code_A9514.02',
#  'marketing code_A9514.04',
#  'marketing code_A9514.07',
#  'marketing code_A9516',
#  'marketing code_A9518',
#  'marketing code_A9522',
#  'marketing code_A9522.01',
#  'marketing code_A9522.02',
#  'marketing code_A9522.03',
#  'marketing code_A9523',
#  'marketing code_A9525',
#  'marketing code_A9535',
#  'marketing code_A9536',
#  'marketing code_A9537',
#  'marketing code_A9556',
#  'marketing code_A9559',
#  'marketing code_A9560',
#  'marketing code_A9580',
#  'marketing code_A9639',
#  'marketing code_A9640',
#  'marketing code_A9670',
#  'marketing code_A9697',
#  'marketing code_A9813',
#  'marketing code_A9814',
#  'marketing code_A9815',
#  'marketing code_A9817',
#  'marketing code_A9818',
#  'marketing code_A9819',
#  'marketing code_A9820',
#  'marketing code_A9821',
#  'marketing code_A9822',
#  'marketing code_A9824',
#  'marketing code_A9842',
#  'marketing code_A9847',
#  'marketing code_A9878',
#  'marketing code_A9883',
#  'marketing code_A9891',
#  'marketing code_A9892',
#  'marketing code_A990',
#  'marketing code_A9902',
#  'marketing code_A992',
#  'marketing code_A994',
#  'marketing code_AH01',
#  'marketing code_AH02',
#  'marketing code_AH03',
#  'marketing code_AH04',
#  'marketing code_AH05',
#  'marketing code_CBAAH01',
#  'marketing code_CBAAH02',
#  'marketing code_CBAAH03',
#  'marketing code_CBAAH04',
#  'marketing code_CBADOM06',
#  'marketing code_CBADOM07',
#  'marketing code_CBADOM09',
#  'marketing code_CBADOM11',
#  'marketing code_CBADOM16',
#  'marketing code_CBADOM23',
#  'marketing code_CBADOM25',
#  'marketing code_CPLDOM06',
#  'marketing code_CPLDOM07',
#  'marketing code_CPLDOM09',
#  'marketing code_CPLDOM11',
#  'marketing code_CPLDOM35',
#  'marketing code_CPLDOM52',
#  'marketing code_CPLDOM53',
#  'marketing code_CPLP0001',
#  'marketing code_DOM01',
#  'marketing code_DOM02',
#  'marketing code_DOM03',
#  'marketing code_DOM05',
#  'marketing code_DOM06',
#  'marketing code_DOM07',
#  'marketing code_DOM09',
#  'marketing code_DOM10',
#  'marketing code_DOM11',
#  'marketing code_DOM12',
#  'marketing code_DOM15',
#  'marketing code_DOM16',
#  'marketing code_DOM23',
#  'marketing code_DOM25',
#  'marketing code_DOM26',
#  'marketing code_DOM27',
#  'marketing code_DOM28',
#  'marketing code_DOM31',
#  'marketing code_DOM32',
#  'marketing code_DOM35',
#  'marketing code_DOM36',
#  'marketing code_DOM37',
#  'marketing code_DOM37.01',
#  'marketing code_DOM37.02',
#  'marketing code_DOM38',
#  'marketing code_DOM39',
#  'marketing code_DOM40',
#  'marketing code_DOM41',
#  'marketing code_DOM45',
#  'marketing code_DOM49',
#  'marketing code_DOM50',
#  'marketing code_DOM52',
#  'marketing code_DOM53',
#  'marketing code_DOM56',
#  'marketing code_EDOM01',
#  'marketing code_EDOM02',
#  'marketing code_EDOM03',
#  'marketing code_EDOM04',
#  'marketing code_EDOM06',
#  'marketing code_EDOM08',
#  'marketing code_EDOM11',
#  'marketing code_EDOM12',
#  'marketing code_EDOM13',
#  'marketing code_EDOM13.01',
#  'marketing code_EDOM13.02',
#  'marketing code_EDOM13.03',
#  'marketing code_EDOM13.10',
#  'marketing code_EDOM13.15',
#  'marketing code_EDOM13.16',
#  'marketing code_EDOM13.17',
#  'marketing code_EDOM13.18',
#  'marketing code_EDOM13.19',
#  'marketing code_EDOM13.21',
#  'marketing code_EDOM13.22',
#  'marketing code_EDOM13.23',
#  'marketing code_EDOM13.24',
#  'marketing code_EDOM13.26',
#  'marketing code_EDOM13.32',
#  'marketing code_EDOM13.33',
#  'marketing code_EDOM13.34',
#  'marketing code_EDOM13.35',
#  'marketing code_EDOM13.36',
#  'marketing code_EDOM14',
#  'marketing code_EDOM15.01',
#  'marketing code_EDOM15.02',
#  'marketing code_EDOM15.03',
#  'marketing code_EDOM16.01',
#  'marketing code_EDOM16.03',
#  'marketing code_EDOM17',
#  'marketing code_EDOM17.02',
#  'marketing code_EDOM18',
#  'marketing code_EDOM19',
#  'marketing code_EX100',
#  'marketing code_FHB01',
#  'marketing code_FHB03',
#  'marketing code_FHB04',
#  'marketing code_FHB05',
#  'marketing code_FHB06',
#  'marketing code_FHB07',
#  'marketing code_FHB08',
#  'marketing code_FHB09',
#  'marketing code_FHB12',
#  'marketing code_FHB13',
#  'marketing code_FHB14',
#  'marketing code_GA01',
#  'marketing code_GA03',
#  'marketing code_GA04',
#  'marketing code_GA05',
#  'marketing code_GA06',
#  'marketing code_GA07',
#  'marketing code_GA09',
#  'marketing code_HS01',
#  'marketing code_HS02',
#  'marketing code_HS04',
#  'marketing code_HS06',
#  'marketing code_HS07',
#  'marketing code_HS08',
#  'marketing code_HS09',
#  'marketing code_HS10',
#  'marketing code_HS11',
#  'marketing code_HS13',
#  'marketing code_HS14',
#  'marketing code_HS15',
#  'marketing code_HS17',
#  'marketing code_HS18',
#  'marketing code_HS19',
#  'marketing code_HS20',
#  'marketing code_HS21',
#  'marketing code_HS22',
#  'marketing code_HS24',
#  'marketing code_HS25',
#  'marketing code_HS26',
#  'marketing code_HS27',
#  'marketing code_HS28',
#  'marketing code_HS29',
#  'marketing code_HS30',
#  'marketing code_HS31',
#  'marketing code_HS32',
#  'marketing code_HS33',
#  'marketing code_HS34',
#  'marketing code_HS35',
#  'marketing code_HS36',
#  'marketing code_IPH',
#  'marketing code_MM02',
#  'marketing code_MM03',
#  'marketing code_MM17',
#  'marketing code_MM21',
#  'marketing code_MM30.01',
#  'marketing code_MM31.02',
#  'marketing code_NS03',
#  'marketing code_NS10',
#  'marketing code_NS13',
#  'marketing code_OME',
#  'marketing code_P0001',
#  'marketing code_P00010',
#  'marketing code_P00011',
#  'marketing code_P00012',
#  'marketing code_P00013',
#  'marketing code_P00014',
#  'marketing code_P00015',
#  'marketing code_P00016',
#  'marketing code_P00018',
#  'marketing code_P00019',
#  'marketing code_P0002',
#  'marketing code_P00021',
#  'marketing code_P00022',
#  'marketing code_P0003',
#  'marketing code_P0004',
#  'marketing code_P0005',
#  'marketing code_P0006',
#  'marketing code_P0007',
#  'marketing code_P0008',
#  'marketing code_P0030',
#  'marketing code_P0032',
#  'marketing code_P0034',
#  'marketing code_REFI02',
#  'marketing code_REFI05',
#  'marketing code_REFI06',
#  'marketing code_REFI07',
#  'marketing code_REFI08',
#  'marketing code_REFI09',
#  'marketing code_REFI10',
#  'marketing code_REFI11',
#  'marketing code_XDOM34',
#  'property use_Investment',
#  'property use_Investment,Other',
#  'property use_Other',
#  'property use_Residence',
#  'property use_Residence,Investment',
#  'property use_Residence,Investment,Other',
#  'property use_Residence,Other']

# %%
# mce = MultiColumnLabelEncoder(columns = encoded_columns);
# df = mce.fit_transform(df)

X = df[df.keys()]
X = df.loc[:,df.columns != target]
y = df[target]

# %%
print("Keys of enquiries_dataset: \n{}".format(X.keys()))
# Out:
# Keys of enquiries_dataset:
# Index(['Marketing Code', 'Suburb', 'State', 'Post Code', 'Classification',
#        'Loan Amount', 'loan_reason', 'property_use', 'Month', 'Day', 'Hour',
#        'Weekday'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# split data and labels into a training and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y,
                     test_size=0.3,
                     random_state=0,
                     stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.learning_curve import learning_curve
from sklearn.pipeline import make_pipeline

pipe_svm = make_pipeline(MultiColumnLabelEncoder(columns = encoded_columns),StandardScaler(),
                         PCA(n_components=2),LogisticRegression(random_state=1))


pipe_svm.fit(X_train, y_train)
y_svm_pred = pipe_svm.predict(X_test)
y_svm_train_pred = pipe_svm.predict(X_train)
# Out:
# /Users/mluo/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/mluo/anaconda3/lib/python3.6/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)
# Pipeline(memory=None,
#      steps=[('multicolumnlabelencoder', <__main__.MultiColumnLabelEncoder object at 0x110555e80>), ('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('pca', PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), (...nalty='l2', random_state=1, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Enquiry Status'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-40334e5bf0ae> in <module>()
#       8                          PCA(n_components=2),LogisticRegression(random_state=1))
#       9 print(pipe_svm)
# ---> 10 pipe_svm.fit(X_train, y_train)
#      11 y_svm_pred = pipe_svm.predict(X_test)
#      12 y_svm_train_pred = pipe_svm.predict(X_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     246             This estimator
#     247         """
# --> 248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
#     250             self._final_estimator.fit(Xt, y, **fit_params)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     211                 Xt, fitted_transformer = fit_transform_one_cached(
#     212                     cloned_transformer, None, Xt, y,
# --> 213                     **fit_params_steps[name])
#     214                 # Replace the transformer of the step with the fitted
#     215                 # transformer. This is necessary when loading the transformer
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     360
#     361     def __call__(self, *args, **kwargs):
# --> 362         return self.func(*args, **kwargs)
#     363
#     364     def call_and_shelve(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, weight, X, y, **fit_params)
#     579                        **fit_params):
#     580     if hasattr(transformer, 'fit_transform'):
# --> 581         res = transformer.fit_transform(X, y, **fit_params)
#     582     else:
#     583         res = transformer.fit(X, y, **fit_params).transform(X)
#
# <ipython-input-6-4165e6c69468> in fit_transform(self, X, y)
#      25
#      26     def fit_transform(self,X,y=None):
# ---> 27         return self.fit(X,y).transform(X)
#
# <ipython-input-6-4165e6c69468> in transform(self, X)
#      18         if self.columns is not None:
#      19             for col in self.columns:
# ---> 20                 output[col] = le.fit_transform(output[col].astype(str))
#      21         else:
#      22             for colname,col in output.iteritems():
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Enquiry Status'

# %%
from sklearn.ensemble import RandomForestClassifier

pipe_rfc = make_pipeline(StandardScaler(),PCA(n_components=2),RandomForestClassifier(n_estimators=10,
                                                                                    random_state=1))

pipe_rfc.fit(X_train, y_train)
y_rfc_train_pred = pipe_rfc.predict(X_train)
y_rfc_pred = pipe_rfc.predict(X_test)

# %%
from sklearn import cross_validation
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score

print("LogisticRegression")
scores = cross_validation.cross_val_score(pipe_svm, X, y, cv=3)
print("cross_validation: {:.2f}".format(np.mean(scores, axis=0)))
print(classification_report(y_test, y_svm_pred))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_svm_train_pred),r2_score(y_test, y_svm_pred)))

print("RandomForest")
scores = cross_validation.cross_val_score(pipe_rfc, X, y, cv=3)
print("cross_validation: {:.2f}".format(np.mean(scores, axis=0)))
print(classification_report(y_test, y_rfc_pred))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_rfc_train_pred),r2_score(y_test, y_rfc_pred)))

# %%
from sklearn.externals import joblib
joblib.dump(pipe_rfc, 'app/models/rfpipeline.pkl')

model_columns = list(X.columns)
joblib.dump(model_columns, 'app/models/rf_model_columns.pkl')
